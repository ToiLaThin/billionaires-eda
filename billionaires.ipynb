# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### EDA

# %%
data = pd.read_csv('./billionaires.csv')
data.head()
# Out:
#    position  wealth               industry                 full_name  age  \
# 0         1  211000       Fashion & Retail  Bernard Arnault & family   74
# 1         2  180000             Automotive                 Elon Musk   51
# 2         3  114000             Technology                Jeff Bezos   59
# 3         4  107000             Technology             Larry Ellison   78
# 4         5  106000  Finance & Investments            Warren Buffett   92
#
#   country_of_residence city_of_residence              source    citizenship  \
# 0               France             Paris                LVMH         France
# 1        United States            Austin       Tesla, SpaceX  United States
# 2        United States            Medina              Amazon  United States
# 3        United States             Lanai              Oracle  United States
# 4        United States             Omaha  Berkshire Hathaway  United States
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2591 entries, 0 to 2590
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   position              2591 non-null   int64
#  1   wealth                2591 non-null   int64
#  2   industry              2591 non-null   object
#  3   full_name             2591 non-null   object
#  4   age                   2591 non-null   int64
#  5   country_of_residence  2591 non-null   object
#  6   city_of_residence     2591 non-null   object
#  7   source                2591 non-null   object
#  8   citizenship           2591 non-null   object
#  9   gender                2591 non-null   object
#  10  birth_date            2591 non-null   object
#  11  last_name             2591 non-null   object
#  12  first_name            2591 non-null   object
#  13  residence_state       2591 non-null   object
#  14  residence_region      2591 non-null   object
# ...

# %%
data.describe()
# Out:
#           position         wealth          age   birth_year  birth_month  \
# count  2591.000000    2591.000000  2591.000000  2591.000000  2591.000000
# mean   1282.913547    4666.190660    65.252798  1957.133925     5.646083
# std     740.191092    9917.104258    13.055442    13.074254     3.732279
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     636.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1272.000000    2400.000000    65.000000  1957.000000     5.000000
# 75%    1905.000000    4300.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#          birth_day   gdp_country  g_tertiary_ed_enroll  g_primary_ed_enroll  \
# count  2591.000000  2.591000e+03           2591.000000          2591.000000
# mean     11.882671  1.102966e+13             64.125743           100.232420
# std       9.941884  9.641891e+12             24.527813            11.966391
# ...

# %%
cols_keeping = [
    'position', 'wealth', 'industry', 'full_name', 'age',
    'city_of_residence', 'country_of_residence', 'gender', 'continent'
]
data = data[cols_keeping]
data.head()
# Out:
#    position  wealth               industry                 full_name  age  \
# 0         1  211000       Fashion & Retail  Bernard Arnault & family   74
# 1         2  180000             Automotive                 Elon Musk   51
# 2         3  114000             Technology                Jeff Bezos   59
# 3         4  107000             Technology             Larry Ellison   78
# 4         5  106000  Finance & Investments            Warren Buffett   92
#
#   city_of_residence country_of_residence gender      continent
# 0             Paris               France      M         Europe
# 1            Austin        United States      M  North America
# 2            Medina        United States      M  North America
# 3             Lanai        United States      M  North America
# 4             Omaha        United States      M  North America

# %%
data['wealth'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Which industry appear most

# %%
data['industry'].hist(bins=50)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Top 10 industries gather most wealth

# %%
where = data.groupby('industry')['wealth'].sum().sort_values(ascending=False).head(10)
where.plot(kind='bar')
where.head(10)
# Out:
# industry
# Technology               1870700
# Fashion & Retail         1675200
# Finance & Investments    1593600
# Manufacturing            1006400
# Food & Beverage           946000
# Diversified               905200
# Real Estate               648800
# Healthcare                638800
# Automotive                516900
# Energy                    453500
# Name: wealth, dtype: int64

# %% [markdown]
# #### Median ,mode age of billionaires from each industry

# %%
where = data.groupby('industry')['age'].agg(['mean', 'median']).sort_values(by='mean', ascending=False).head(10)
where.plot(kind='bar')
where.head(10)
# Out:
#                          mean  median
# industry
# Sports              69.025641    71.0
# Diversified         68.737968    69.0
# Logistics           68.526316    68.0
# Gambling & Casinos  68.520000    71.0
# Real Estate         68.172775    69.0
# Service             67.773585    69.0
# Energy              67.560000    67.0
# Fashion & Retail    67.038314    69.0
# Food & Beverage     66.739130    68.0
# Telecom             66.733333    67.0

# %% [markdown]
# #### Top 5 country have most billionaires

# %%
where = data.groupby('country_of_residence')['position'].agg(['count']).sort_values(by='count', ascending=False).head(10)
where.plot(kind='bar')
where.head(10)
# Out:
#                       count
# country_of_residence
# United States           754
# China                   515
# India                   157
# Germany                 102
# United Kingdom           82
# Russia                   79
# Switzerland              78
# Hong Kong                67
# Italy                    55
# Singapore                45

# %% [markdown]
# #### For india, top 3 industry have most millionaires

# %%
where = data[data['country_of_residence'] == 'India'].groupby('industry')['position'].agg(['count']).sort_values(by='count', ascending=False).head(3)
where.plot(kind='bar')
where.head(3)
# Out:
#                count
# industry
# Manufacturing     32
# Healthcare        29
# Diversified       22

# %% [markdown]
# #### For india, top 3 industry have richest billionaires

# %%
where = data[data['country_of_residence'] == 'India'].groupby('industry')['wealth'].agg(['max']).sort_values(by='max', ascending=False).head(3)
where.plot(kind='bar')
where.head(3)
# Out:
#                max
# industry
# Diversified  83400
# Technology   25600
# Healthcare   22600

# %% [markdown]
# ### Preprocessing

# %%
# get more than .5
data.corr()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_5540\1406162548.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#           position    wealth       age
# position  1.000000 -0.448660 -0.142681
# wealth   -0.448660  1.000000  0.065946
# age      -0.142681  0.065946  1.000000

# %%
data.isnull().sum()
# Out:
# position                0
# wealth                  0
# industry                0
# full_name               0
# age                     0
# city_of_residence       0
# country_of_residence    0
# gender                  0
# continent               0
# dtype: int64
